# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\python\Exam_score_predictor_using_ML\Data\cleaned_student_data.csv")
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
print(f"size: {df.size}")
print(df.isnull().sum())
# Out:
# size: 14544
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ['study_hours_per_day','attendance_percentage', 'sleep_hours','mental_health_rating','part_time_job']

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 904                  2.6                   77.0          7.5
# 905                  2.9                   86.0          6.8
# 906                  3.0                   61.9          6.5
# 907                  5.4                  100.0          7.6
# 908                  4.3                   89.4          7.1
#
#      mental_health_rating part_time_job  exam_score
# 0                       8            No        56.2
# 1                       8            No       100.0
# 2                       1            No        34.3
# 3                       1            No        26.8
# 4                       1            No        66.4
# ..                    ...           ...         ...
# 904                     6            No        76.1
# 905                     6           Yes        65.9
# 906                     9            No        64.4
# 907                     1           Yes        69.7
# 908                     8            No        74.9
#
# [909 rows x 6 columns]

# %%
le = LabelEncoder()

# %%
df_model['part_time_job'] =  le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 904                  2.6                   77.0          7.5
# 905                  2.9                   86.0          6.8
# 906                  3.0                   61.9          6.5
# 907                  5.4                  100.0          7.6
# 908                  4.3                   89.4          7.1
#
#      mental_health_rating  part_time_job  exam_score
# 0                       8              0        56.2
# 1                       8              0       100.0
# 2                       1              0        34.3
# 3                       1              0        26.8
# 4                       1              0        66.4
# ..                    ...            ...         ...
# 904                     6              0        76.1
# 905                     6              1        65.9
# 906                     9              0        64.4
# 907                     1              1        69.7
# 908                     8              0        74.9
#
# [909 rows x 6 columns]

# %%
X = df_model[features]
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression":{
        "model" : LinearRegression(),
        "params" : {}
    },
    "DecisionTree":{
        "model" : DecisionTreeRegressor(),
        "params" : {"max_depth" : [3,5,10], "min_samples_split" : [2,5]}
    },
    "RandomForest" : {
        "model" : RandomForestRegressor(),
        "params" : {"n_estimators" : [50,100], "max_depth": [5,10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(config["model"],config["params"],cv = 5, scoring = "neg_mean_squared_error")
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model" : name,
        "best_params" : grid.best_params_,
        "rmse" : rmse,
        "r2" : r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': 7.376812995425731,
#   'r2': 0.7968894383350734},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': 9.189274088907542,
#   'r2': 0.6848209299232596},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': 7.999015848171348,
#   'r2': 0.761181441064197}]

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.376813
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.999016
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  9.189274
#
#          r2
# 0  0.796889
# 2  0.761181
# 1  0.684821

# %%
import joblib

best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   7.376813
# r2                     0.796889
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model_pkl")
# Out:
# ['best_model_pkl']

# %%
joblib.load("best_model_pkl").predict(X_test)
# Out:
# array([ 69.65327425, 101.49785175,  57.67033365,  61.28183191,
#         63.56874464,  54.1809859 , 102.62470515,  41.0826638 ,
#         57.71722366,  77.22484193, 115.32425793,  67.24642978,
#         57.96780871,  37.5268067 ,  52.76981731,  80.08715057,
#         44.07954472,  85.58995874,  66.75598134,  80.04701348,
#         60.70117069,  69.88236463,  67.3409568 ,  52.04571946,
#         77.0077602 ,  70.5947591 ,  86.38678834,  67.33884728,
#         56.84795774,  69.95368226,  72.4395309 ,  71.62634586,
#         42.12695617,  53.13689169,  62.0019684 ,  73.3095103 ,
#         69.29900088,  77.48107335,  94.26716699,  46.42355805,
#         81.85562938,  40.60113112,  70.1122084 ,  85.07548216,
#         94.48143692,  74.26344109,  66.70036983,  48.92767151,
#         54.97205488,  47.21912588,  69.51599848,  71.14315062,
#         91.52584331,  88.32100125,  84.45415703,  63.64137371,
#         83.02517528,  63.08783432,  98.07031515,  68.31359587,
#         61.0234794 ,  81.1148883 ,  77.45864808,  62.14063155,
#         76.53481528,  74.83885426,  76.68472104,  76.52318174,
#         54.55013746,  54.27941821,  55.57788334,  85.35394269,
#         82.27551134,  79.36878895,  83.69220041,  59.38276315,
#         56.50647088,  72.24230521,  64.87101299,  59.86149389,
#         73.33758565,  80.61992577,  70.20854282,  61.2642645 ,
#         78.49984679,  46.52666247,  70.40477667,  85.86069868,
#         55.22074637,  84.20309395,  66.54423847,  68.8899433 ,
#         68.01649762,  90.35284716,  66.25211042,  73.35099897,
#         78.99961143,  80.85364674,  34.07217639,  63.44842876,
#         54.1048007 ,  93.29678994,  52.60961208,  80.36926071,
#         64.7719743 ,  95.61742841,  99.38541188,  49.45186634,
#         91.69729711,  78.70663792,  45.70477712,  60.05075545,
#         74.92637312,  70.05705221,  75.52807025,  87.69201972,
#         64.33742269,  75.86463252,  68.30053395,  74.59529628,
#         88.24077353,  45.97432955,  51.96864857,  65.58871377,
#         64.9023466 ,  85.2652158 ,  71.17382137,  76.9384696 ,
#         86.85962666,  80.39472169,  71.56094773,  68.48671733,
#         64.74589097,  57.45957817,  64.81476205,  97.71483999,
#         66.16326409,  75.85209083,  70.63722799,  64.69940863,
#         76.75958523,  67.1142276 ,  71.09065397,  61.41756477,
#         93.02561935,  57.48846515,  73.59376451,  83.87763264,
#         55.66431716,  50.56118245,  81.86159654,  71.80449683,
#         58.02616961,  64.94639018,  82.57292072,  53.68824906,
#         94.31676369, 104.70803339,  73.07490187,  80.70978686,
#         79.68363838,  93.907731  ,  87.78875123,  78.30936564,
#         80.45227491,  74.53698275,  91.49334267, 111.48229376,
#         73.63145597,  63.64001696,  70.32196933,  85.05701304,
#         96.41397838,  68.38334944,  71.48891272,  71.53255701,
#         77.38615468,  72.64278476,  67.06989821,  69.35389946,
#         53.80314099, 109.86076479])
